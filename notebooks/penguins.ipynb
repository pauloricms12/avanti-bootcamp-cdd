# %%
import pandas as pd
import seaborn as sns
import numpy as np

# %%
penguins = sns.load_dataset("penguins")
penguins.to_csv('../data/raw/penguins.csv', index=False)

# %%
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
dicionario = pd.DataFrame([
    {
        "variavel":"species",
        "descricao": "Nome da Espécie",
        "tipo":"qualitativa",
        "subtipo":"nominal"
    },{
        "variavel":"island",
        "descricao": "Ilha que foi feita a medição",
        "tipo":"qualitativa",
        "subtipo":"nominal"
    },{
        "variavel":"bill_length_mm",
        "descricao": "Comprimento do bico em mm",
        "tipo":"quantitativa",
        "subtipo":"continua"
    },{
        "variavel":"bill_depth_mm",
        "descricao": "Profunidade (altura) do bico em mm",
        "tipo":"quantitativa",
        "subtipo":"continua"
    },{
        "variavel":"flipper_length_mm",
        "descricao": "Comprimento da nadadeira em mm",
        "tipo":"quantitativa",
        "subtipo":"continua"
    },{
        "variavel":"body_mass_g",
        "descricao": "Massa do corpo em gramas",
        "tipo":"quantitativa",
        "subtipo":"continua"
    },{
        "variavel":"sex",
        "descricao": "Sexo dos penguins",
        "tipo":"qualitativa",
        "subtipo":"nominal"
    }
])

# %%
dicionario
# Out:
#             variavel                           descricao          tipo  \
# 0            species                     Nome da Espécie   qualitativa
# 1             island        Ilha que foi feita a medição   qualitativa
# 2     bill_length_mm           Comprimento do bico em mm  quantitativa
# 3      bill_depth_mm  Profunidade (altura) do bico em mm  quantitativa
# 4  flipper_length_mm      Comprimento da nadadeira em mm  quantitativa
# 5        body_mass_g            Massa do corpo em gramas  quantitativa
# 6                sex                   Sexo dos penguins   qualitativa
#
#     subtipo
# 0   nominal
# 1   nominal
# 2  continua
# 3  continua
# 4  continua
# 5  continua
# 6   nominal

# %%
dicionario.to_csv('../data/external/dictionary.csv', index=False)
